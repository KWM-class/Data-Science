# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
## Author

Kyle M.

# %% [markdown]
# # Title
# Data Science Tools and Ecosystem

# %% [markdown]
# # Introduction
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - List popular languages used in Data Science
# - Identify common data science tools and development environments
# - Explore key data science libraries for analysis, visualization, and machine learning
# - Understand how to evaluate arithmetic expressions in Python
# - Convert real-world quantities (e.g., minutes to hours) using Python expressions

# %% [markdown]
# ## Data Science Languages
#
# Below are some of the most commonly used programming languages in data science:
#
# - **Python** – Widely used for data analysis, machine learning, automation, and visualization.
# - **R** – Designed specifically for statistical analysis and data visualization.
# - **SQL** – Essential for querying, managing, and manipulating data stored in databases.
#
# These languages form the foundation for most modern data science workflows and tools.

# %% [markdown]
# ## Data Science Libraries
#
# Below are some widely used libraries and frameworks in data science:
#
# ### **Python Libraries**
# - **NumPy** – Fundamental package for numerical computing
# - **Pandas** – Data manipulation and analysis
#
# ### **R Libraries**
# - **ggplot2** – Data visualization
# - **dplyr** – Data manipulation
#
# ### **Big Data / Distributed Computing**
# - **Apache Spark** – Distributed data processing
# - **Hadoop** – Large-scale data storage and processing framework
#
# These libraries provide the core functionality needed for data cleaning, analysis, visualization, machine learning, and large-scale computation.

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools     |
# |------------------------|
# | Jupyter Notebook       |
# | JupyterLab             |
# | Visual Studio Code     |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# Arithmetic expressions allow Python to perform basic mathematical operations such as addition, subtraction, multiplication, and division. The following examples demonstrate how Python evaluates these expressions and returns numerical results.

# %%
# This is a simple arithmetic expression to multiply then add integers.
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
200 / 60
# Out:
# 3.3333333333333335
